# %%
from sympy import *

init_session()
# Out:
# IPython console for SymPy 1.6 (Python 3.8.2-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.6/

# %%
from fractions import Fraction

qsi = symbols("xi")
eta = symbols("eta")

N1_expr = Fraction(1, 4) * (1 - eta) * (1 - qsi)
N2_expr = Fraction(1, 4) * (1 + eta) * (1 - qsi)
N3_expr = Fraction(1, 4) * (1 + eta) * (1 + qsi)
N4_expr = Fraction(1, 4) * (1 - eta) * (1 + qsi)

N1, N2, N3, N4 = symbols("N_1^{(e)} N_2^{(e)} N_3^{(e)} N_4^{(e)}")

Ne = Matrix([[N1, 0, N2, 0, N3, 0, N4, 0], [0, N1, 0, N2, 0, N3, 0, N4]])
Ne
# Out:
# ⎡N_1__{(e)}      0       N_2__{(e)}      0       N_3__{(e)}      0       N_4__
# ⎢
# ⎣    0       N_1__{(e)}      0       N_2__{(e)}      0       N_3__{(e)}      0
#
# {(e)}      0     ⎤
#                  ⎥
#        N_4__{(e)}⎦

# %%
x, y, l = symbols("x y l")

x1, y1 = symbols("x_1 y_1")

x_qsi = l/2 * qsi + x1 + l*(sqrt(2)/2)
y_eta = l/2 * eta + y1 + l*(sqrt(2)/2)

qsi_x = (2/l) * (x - x1 - l*(sqrt(2)/2))
eta_y = (2/l) * (y - y1 - l*(sqrt(2)/2))

N = dict()
Ns = [0, N1_expr, N2_expr, N3_expr, N4_expr]
for i in (x, y):
    for k in range(1, 4 + 1):
        N[(i, k)] = simplify((diff(Ns[k], qsi) * diff(qsi_x, i) + diff(Ns[k], eta) * diff(eta_y, i)))
N
# Out:
# ⎧        η - 1          -(η + 1)           η + 1          1 - η          ξ - 1
# ⎨(x, 1): ─────, (x, 2): ─────────, (x, 3): ─────, (x, 4): ─────, (y, 1): ─────
# ⎩         2⋅l              2⋅l              2⋅l            2⋅l            2⋅l
#
#           1 - ξ          ξ + 1          -(ξ + 1) ⎫
# , (y, 2): ─────, (y, 3): ─────, (y, 4): ─────────⎬
#            2⋅l            2⋅l              2⋅l   ⎭

# %%
B_matrix = Matrix([[N[(x, (i//2) + 1)] if i % 2 == 0 else 0 for i in range(8)],
                   [N[(y, (i//2) + 1)] if i % 2 == 1 else 0 for i in range(8)],
                   [N[(y if i % 2 == 0 else x, (i//2) + 1)] for i in range(8)]])

B = MatrixSymbol("B", 3, 8)

B_matrix
# Out:
# ⎡η - 1         -(η + 1)              η + 1           1 - η             ⎤
# ⎢─────    0    ─────────      0      ─────    0      ─────        0    ⎥
# ⎢ 2⋅l             2⋅l                 2⋅l             2⋅l              ⎥
# ⎢                                                                      ⎥
# ⎢       ξ - 1               1 - ξ           ξ + 1             -(ξ + 1) ⎥
# ⎢  0    ─────      0        ─────      0    ─────      0      ─────────⎥
# ⎢        2⋅l                 2⋅l             2⋅l                 2⋅l   ⎥
# ⎢                                                                      ⎥
# ⎢ξ - 1  η - 1    1 - ξ    -(η + 1)   ξ + 1  η + 1  -(ξ + 1)     1 - η  ⎥
# ⎢─────  ─────    ─────    ─────────  ─────  ─────  ─────────    ─────  ⎥
# ⎣ 2⋅l    2⋅l      2⋅l        2⋅l      2⋅l    2⋅l      2⋅l        2⋅l   ⎦

# %%
t, v, E = symbols("t nu E")
E_m = MatrixSymbol("E", 3, 3)
E_matrix = simplify((E/(1 - v**2)) * Matrix([[1, v,        0],
                                             [v, 1,        0],
                                             [0, 0, (1 -v)/2]]))
K = MatrixSymbol("K", 8, 8)
Eq(K, Integral(t * B.T * E_m * B, (qsi, -1, 1), (eta, -1, 1)), evaluate=False)
# Out:
#     1  1
#     ⌠  ⌠
#     ⎮  ⎮     T
# K = ⎮  ⎮  t⋅B ⋅E⋅B dξ dη
#     ⌡  ⌡
#     -1 -1

# %%
K_matrix = B.T * E_m * B
K_matrix = K_matrix.subs({E_m: E_matrix, B: B_matrix}).doit()

K_matrix = t * K_matrix

K_matrix
# Out:
# ⎡       ⎛             2              2 ⎞
# ⎢       ⎜    E⋅(η - 1)      E⋅(ξ - 1)  ⎟          ⎛  E⋅ν⋅(η - 1)⋅(ξ - 1)   E⋅(
# ⎢     t⋅⎜- ───────────── + ────────────⎟        t⋅⎜- ─────────────────── + ───
# ⎢       ⎜     2 ⎛ 2    ⎞      2        ⎟          ⎜        2 ⎛ 2    ⎞
# ⎢       ⎝  4⋅l ⋅⎝ν  - 1⎠   8⋅l ⋅(ν + 1)⎠          ⎝     4⋅l ⋅⎝ν  - 1⎠
# ⎢
# ⎢                                                       ⎛          2
# ⎢  ⎛  E⋅ν⋅(η - 1)⋅(ξ - 1)   E⋅(η - 1)⋅(ξ - 1)⎞          ⎜ E⋅(η - 1)       E⋅(ξ
# ⎢t⋅⎜- ─────────────────── + ─────────────────⎟        t⋅⎜──────────── - ──────
# ⎢  ⎜        2 ⎛ 2    ⎞            2          ⎟          ⎜   2              2 ⎛
# ⎢  ⎝     4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠          ⎝8⋅l ⋅(ν + 1)   4⋅l ⋅⎝
# ⎢
# ⎢
# ⎢    ⎛E⋅(1 - ξ)⋅(ξ - 1)   E⋅(η - 1)⋅(η + 1)⎞       ⎛E⋅ν⋅(η + 1)⋅(ξ - 1)   E⋅(1
# ⎢  t⋅⎜───────────────── + ─────────────────⎟     t⋅⎜─────────────────── + ────
# ⎢    ⎜      2                  2 ⎛ 2    ⎞  ⎟       ⎜      2 ⎛ 2    ⎞
# ⎢    ⎝   8⋅l ⋅(ν + 1)       4⋅l ⋅⎝ν  - 1⎠  ⎠       ⎝   4⋅l ⋅⎝ν  - 1⎠         8
# ⎢
# ⎢
# ⎢  ⎛  E⋅ν⋅(1 - ξ)⋅(η - 1)   E⋅(η + 1)⋅(ξ - 1)⎞     ⎛  E⋅(1 - ξ)⋅(ξ - 1)   E⋅(η
# ⎢t⋅⎜- ─────────────────── - ─────────────────⎟   t⋅⎜- ───────────────── - ────
# ⎢  ⎜        2 ⎛ 2    ⎞            2          ⎟     ⎜       2 ⎛ 2    ⎞
# ⎢  ⎝     4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠     ⎝    4⋅l ⋅⎝ν  - 1⎠        8
# ⎢
# ⎢
# ⎢   ⎛  E⋅(η - 1)⋅(η + 1)   E⋅(ξ - 1)⋅(ξ + 1)⎞     ⎛  E⋅ν⋅(η + 1)⋅(ξ - 1)   E⋅(
# ⎢ t⋅⎜- ───────────────── + ─────────────────⎟   t⋅⎜- ─────────────────── + ───
# ⎢   ⎜       2 ⎛ 2    ⎞           2          ⎟     ⎜        2 ⎛ 2    ⎞
# ⎢   ⎝    4⋅l ⋅⎝ν  - 1⎠        8⋅l ⋅(ν + 1)  ⎠     ⎝     4⋅l ⋅⎝ν  - 1⎠
# ⎢
# ⎢
# ⎢  ⎛  E⋅ν⋅(η - 1)⋅(ξ + 1)   E⋅(η + 1)⋅(ξ - 1)⎞      ⎛E⋅(η - 1)⋅(η + 1)   E⋅(ξ
# ⎢t⋅⎜- ─────────────────── + ─────────────────⎟    t⋅⎜───────────────── - ─────
# ⎢  ⎜        2 ⎛ 2    ⎞            2          ⎟      ⎜      2
# ⎢  ⎝     4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠      ⎝   8⋅l ⋅(ν + 1)       4⋅l
# ⎢
# ⎢
# ⎢   ⎛  E⋅(1 - η)⋅(η - 1)   E⋅(ξ - 1)⋅(ξ + 1)⎞     ⎛  E⋅ν⋅(1 - η)⋅(ξ - 1)   E⋅(
# ⎢ t⋅⎜- ───────────────── - ─────────────────⎟   t⋅⎜- ─────────────────── - ───
# ⎢   ⎜       2 ⎛ 2    ⎞           2          ⎟     ⎜        2 ⎛ 2    ⎞
# ⎢   ⎝    4⋅l ⋅⎝ν  - 1⎠        8⋅l ⋅(ν + 1)  ⎠     ⎝     4⋅l ⋅⎝ν  - 1⎠
# ⎢
# ⎢
# ⎢   ⎛E⋅ν⋅(η - 1)⋅(ξ + 1)   E⋅(1 - η)⋅(ξ - 1)⎞       ⎛E⋅(1 - η)⋅(η - 1)   E⋅(ξ
# ⎢ t⋅⎜─────────────────── + ─────────────────⎟     t⋅⎜───────────────── + ─────
# ⎢   ⎜      2 ⎛ 2    ⎞            2          ⎟       ⎜      2
# ⎣   ⎝   4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠       ⎝   8⋅l ⋅(ν + 1)       4⋅l
#
#
# η - 1)⋅(ξ - 1)⎞      ⎛E⋅(1 - ξ)⋅(ξ - 1)   E⋅(η - 1)⋅(η + 1)⎞      ⎛  E⋅ν⋅(1 -
# ──────────────⎟    t⋅⎜───────────────── + ─────────────────⎟    t⋅⎜- ─────────
#    2          ⎟      ⎜      2                  2 ⎛ 2    ⎞  ⎟      ⎜        2 ⎛
# 8⋅l ⋅(ν + 1)  ⎠      ⎝   8⋅l ⋅(ν + 1)       4⋅l ⋅⎝ν  - 1⎠  ⎠      ⎝     4⋅l ⋅⎝
#
#      2 ⎞
#  - 1)  ⎟            ⎛E⋅ν⋅(η + 1)⋅(ξ - 1)   E⋅(1 - ξ)⋅(η - 1)⎞      ⎛  E⋅(1 - ξ
# ───────⎟          t⋅⎜─────────────────── + ─────────────────⎟    t⋅⎜- ────────
#  2    ⎞⎟            ⎜      2 ⎛ 2    ⎞            2          ⎟      ⎜       2 ⎛
# ν  - 1⎠⎠            ⎝   4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠      ⎝    4⋅l ⋅⎝
#
#                          ⎛          2               2 ⎞
#  - ξ)⋅(η - 1)⎞           ⎜ E⋅(1 - ξ)       E⋅(η + 1)  ⎟            ⎛E⋅ν⋅(1 - ξ
# ─────────────⎟         t⋅⎜──────────── - ─────────────⎟          t⋅⎜──────────
#   2          ⎟           ⎜   2              2 ⎛ 2    ⎞⎟            ⎜      2 ⎛
# ⋅l ⋅(ν + 1)  ⎠           ⎝8⋅l ⋅(ν + 1)   4⋅l ⋅⎝ν  - 1⎠⎠            ⎝   4⋅l ⋅⎝ν
#
#                                                                        ⎛
#  - 1)⋅(η + 1)⎞      ⎛E⋅ν⋅(1 - ξ)⋅(η + 1)   E⋅(1 - ξ)⋅(η + 1)⎞          ⎜    E⋅
# ─────────────⎟    t⋅⎜─────────────────── - ─────────────────⎟        t⋅⎜- ────
#   2          ⎟      ⎜      2 ⎛ 2    ⎞            2          ⎟          ⎜     2
# ⋅l ⋅(ν + 1)  ⎠      ⎝   4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠          ⎝  4⋅l
#
#                        ⎛                               2 ⎞
# η - 1)⋅(ξ + 1)⎞        ⎜E⋅(1 - ξ)⋅(ξ + 1)     E⋅(η + 1)  ⎟        ⎛  E⋅ν⋅(1 -
# ──────────────⎟      t⋅⎜───────────────── + ─────────────⎟      t⋅⎜- ─────────
#    2          ⎟        ⎜      2                2 ⎛ 2    ⎞⎟        ⎜        2 ⎛
# 8⋅l ⋅(ν + 1)  ⎠        ⎝   8⋅l ⋅(ν + 1)     4⋅l ⋅⎝ν  - 1⎠⎠        ⎝     4⋅l ⋅⎝
#
#                                                                      ⎛
# - 1)⋅(ξ + 1)⎞       ⎛E⋅ν⋅(η + 1)⋅(ξ + 1)   E⋅(1 - ξ)⋅(η + 1)⎞        ⎜  E⋅(1 -
# ────────────⎟     t⋅⎜─────────────────── + ─────────────────⎟      t⋅⎜- ──────
# 2 ⎛ 2    ⎞  ⎟       ⎜      2 ⎛ 2    ⎞            2          ⎟        ⎜       2
#  ⋅⎝ν  - 1⎠  ⎠       ⎝   4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠        ⎝    4⋅l
#
#
# η - 1)⋅(ξ + 1)⎞      ⎛E⋅(1 - η)⋅(η + 1)   E⋅(1 - ξ)⋅(ξ + 1)⎞      ⎛  E⋅ν⋅(1 -
# ──────────────⎟    t⋅⎜───────────────── - ─────────────────⎟    t⋅⎜- ─────────
#    2          ⎟      ⎜     2 ⎛ 2    ⎞           2          ⎟      ⎜        2 ⎛
# 8⋅l ⋅(ν + 1)  ⎠      ⎝  4⋅l ⋅⎝ν  - 1⎠        8⋅l ⋅(ν + 1)  ⎠      ⎝     4⋅l ⋅⎝
#
#
# - 1)⋅(ξ + 1)⎞      ⎛  E⋅ν⋅(η + 1)⋅(ξ + 1)   E⋅(1 - η)⋅(1 - ξ)⎞     ⎛  E⋅(1 - η
# ────────────⎟    t⋅⎜- ─────────────────── + ─────────────────⎟   t⋅⎜- ────────
# 2 ⎛ 2    ⎞  ⎟      ⎜        2 ⎛ 2    ⎞            2          ⎟     ⎜        2
#  ⋅⎝ν  - 1⎠  ⎠      ⎝     4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠     ⎝     8⋅l ⋅
#
#
# ξ)⋅(η - 1)   E⋅(η + 1)⋅(ξ - 1)⎞     ⎛  E⋅(η - 1)⋅(η + 1)   E⋅(ξ - 1)⋅(ξ + 1)⎞
# ────────── - ─────────────────⎟   t⋅⎜- ───────────────── + ─────────────────⎟
#  2    ⎞            2          ⎟     ⎜       2 ⎛ 2    ⎞           2          ⎟
# ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠     ⎝    4⋅l ⋅⎝ν  - 1⎠        8⋅l ⋅(ν + 1)  ⎠
#
#
# )⋅(ξ - 1)   E⋅(η - 1)⋅(η + 1)⎞     ⎛  E⋅ν⋅(η + 1)⋅(ξ - 1)   E⋅(η - 1)⋅(ξ + 1)⎞
# ───────── - ─────────────────⎟   t⋅⎜- ─────────────────── + ─────────────────⎟
#  2    ⎞           2          ⎟     ⎜        2 ⎛ 2    ⎞            2          ⎟
# ν  - 1⎠        8⋅l ⋅(ν + 1)  ⎠     ⎝     4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠
#
#                                        ⎛                               2 ⎞
# )⋅(η + 1)   E⋅(1 - ξ)⋅(η + 1)⎞         ⎜E⋅(1 - ξ)⋅(ξ + 1)     E⋅(η + 1)  ⎟
# ───────── - ─────────────────⎟       t⋅⎜───────────────── + ─────────────⎟
# 2    ⎞            2          ⎟         ⎜      2                2 ⎛ 2    ⎞⎟
#   - 1⎠         8⋅l ⋅(ν + 1)  ⎠         ⎝   8⋅l ⋅(ν + 1)     4⋅l ⋅⎝ν  - 1⎠⎠
#
#        2              2 ⎞
# (1 - ξ)      E⋅(η + 1)  ⎟          ⎛  E⋅ν⋅(1 - ξ)⋅(η + 1)   E⋅(η + 1)⋅(ξ + 1)⎞
# ───────── + ────────────⎟        t⋅⎜- ─────────────────── - ─────────────────⎟
#  ⎛ 2    ⎞      2        ⎟          ⎜        2 ⎛ 2    ⎞            2          ⎟
# ⋅⎝ν  - 1⎠   8⋅l ⋅(ν + 1)⎠          ⎝     4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠
#
#                                         ⎛             2              2 ⎞
# ξ)⋅(η + 1)   E⋅(η + 1)⋅(ξ + 1)⎞         ⎜    E⋅(η + 1)      E⋅(ξ + 1)  ⎟
# ────────── - ─────────────────⎟       t⋅⎜- ───────────── + ────────────⎟
#  2    ⎞            2          ⎟         ⎜     2 ⎛ 2    ⎞      2        ⎟
# ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠         ⎝  4⋅l ⋅⎝ν  - 1⎠   8⋅l ⋅(ν + 1)⎠
#
#                         2 ⎞
#  ξ)⋅(ξ + 1)    E⋅(η + 1)  ⎟        ⎛  E⋅ν⋅(η + 1)⋅(ξ + 1)   E⋅(η + 1)⋅(ξ + 1)⎞
# ─────────── - ────────────⎟      t⋅⎜- ─────────────────── + ─────────────────⎟
#  ⎛ 2    ⎞        2        ⎟        ⎜        2 ⎛ 2    ⎞            2          ⎟
# ⋅⎝ν  - 1⎠     8⋅l ⋅(ν + 1)⎠        ⎝     4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠
#
#                                       ⎛                                2 ⎞
# η)⋅(1 - ξ)   E⋅(η + 1)⋅(ξ + 1)⎞       ⎜  E⋅(1 - η)⋅(η + 1)    E⋅(ξ + 1)  ⎟
# ────────── + ─────────────────⎟     t⋅⎜- ───────────────── - ────────────⎟
#  2    ⎞            2          ⎟       ⎜       2 ⎛ 2    ⎞        2        ⎟
# ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠       ⎝    4⋅l ⋅⎝ν  - 1⎠     8⋅l ⋅(ν + 1)⎠
#
#
# )⋅(η + 1)   E⋅(1 - ξ)⋅(ξ + 1)⎞      ⎛E⋅ν⋅(η + 1)⋅(ξ + 1)   E⋅(1 - η)⋅(ξ + 1)⎞
# ───────── + ─────────────────⎟    t⋅⎜─────────────────── + ─────────────────⎟
#                  2 ⎛ 2    ⎞  ⎟      ⎜      2 ⎛ 2    ⎞            2          ⎟
# (ν + 1)       4⋅l ⋅⎝ν  - 1⎠  ⎠      ⎝   4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠
#
#
#     ⎛  E⋅ν⋅(η - 1)⋅(ξ + 1)   E⋅(η + 1)⋅(ξ - 1)⎞     ⎛  E⋅(1 - η)⋅(η - 1)   E⋅(
#   t⋅⎜- ─────────────────── + ─────────────────⎟   t⋅⎜- ───────────────── - ───
#     ⎜        2 ⎛ 2    ⎞            2          ⎟     ⎜       2 ⎛ 2    ⎞
#     ⎝     4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠     ⎝    4⋅l ⋅⎝ν  - 1⎠
#
#
#       ⎛E⋅(η - 1)⋅(η + 1)   E⋅(ξ - 1)⋅(ξ + 1)⎞      ⎛  E⋅ν⋅(1 - η)⋅(ξ - 1)   E⋅
#     t⋅⎜───────────────── - ─────────────────⎟    t⋅⎜- ─────────────────── - ──
#       ⎜      2                  2 ⎛ 2    ⎞  ⎟      ⎜        2 ⎛ 2    ⎞
#       ⎝   8⋅l ⋅(ν + 1)       4⋅l ⋅⎝ν  - 1⎠  ⎠      ⎝     4⋅l ⋅⎝ν  - 1⎠
#
#
#      ⎛E⋅ν⋅(η + 1)⋅(ξ + 1)   E⋅(1 - ξ)⋅(η + 1)⎞       ⎛E⋅(1 - η)⋅(η + 1)   E⋅(1
#    t⋅⎜─────────────────── + ─────────────────⎟     t⋅⎜───────────────── - ────
#      ⎜      2 ⎛ 2    ⎞            2          ⎟       ⎜     2 ⎛ 2    ⎞
#      ⎝   4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠       ⎝  4⋅l ⋅⎝ν  - 1⎠        8
#
#        ⎛                                2 ⎞
#        ⎜  E⋅(1 - ξ)⋅(ξ + 1)    E⋅(η + 1)  ⎟        ⎛  E⋅ν⋅(1 - η)⋅(1 - ξ)   E⋅
#      t⋅⎜- ───────────────── - ────────────⎟      t⋅⎜- ─────────────────── + ──
#        ⎜       2 ⎛ 2    ⎞        2        ⎟        ⎜        2 ⎛ 2    ⎞
#        ⎝    4⋅l ⋅⎝ν  - 1⎠     8⋅l ⋅(ν + 1)⎠        ⎝     4⋅l ⋅⎝ν  - 1⎠
#
#                                                       ⎛
#     ⎛  E⋅ν⋅(η + 1)⋅(ξ + 1)   E⋅(η + 1)⋅(ξ + 1)⎞       ⎜  E⋅(1 - η)⋅(η + 1)
#   t⋅⎜- ─────────────────── + ─────────────────⎟     t⋅⎜- ───────────────── - ─
#     ⎜        2 ⎛ 2    ⎞            2          ⎟       ⎜       2 ⎛ 2    ⎞
#     ⎝     4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠       ⎝    4⋅l ⋅⎝ν  - 1⎠     8
#
#           ⎛          2               2 ⎞
#           ⎜ E⋅(η + 1)       E⋅(ξ + 1)  ⎟           ⎛  E⋅ν⋅(1 - η)⋅(ξ + 1)   E⋅
#         t⋅⎜──────────── - ─────────────⎟         t⋅⎜- ─────────────────── - ──
#           ⎜   2              2 ⎛ 2    ⎞⎟           ⎜        2 ⎛ 2    ⎞
#           ⎝8⋅l ⋅(ν + 1)   4⋅l ⋅⎝ν  - 1⎠⎠           ⎝     4⋅l ⋅⎝ν  - 1⎠
#
#                                                         ⎛             2
#     ⎛  E⋅ν⋅(1 - η)⋅(ξ + 1)   E⋅(η + 1)⋅(ξ + 1)⎞         ⎜    E⋅(1 - η)      E⋅
#   t⋅⎜- ─────────────────── - ─────────────────⎟       t⋅⎜- ───────────── + ───
#     ⎜        2 ⎛ 2    ⎞            2          ⎟         ⎜     2 ⎛ 2    ⎞
#     ⎝     4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠         ⎝  4⋅l ⋅⎝ν  - 1⎠   8⋅l
#
#         ⎛                               2 ⎞
#         ⎜E⋅(1 - η)⋅(η + 1)     E⋅(ξ + 1)  ⎟         ⎛E⋅ν⋅(1 - η)⋅(ξ + 1)   E⋅(
#       t⋅⎜───────────────── + ─────────────⎟       t⋅⎜─────────────────── - ───
#         ⎜      2                2 ⎛ 2    ⎞⎟         ⎜      2 ⎛ 2    ⎞
#         ⎝   8⋅l ⋅(ν + 1)     4⋅l ⋅⎝ν  - 1⎠⎠         ⎝   4⋅l ⋅⎝ν  - 1⎠
#
#                                                                ⎤
# ξ - 1)⋅(ξ + 1)⎞      ⎛E⋅ν⋅(η - 1)⋅(ξ + 1)   E⋅(1 - η)⋅(ξ - 1)⎞ ⎥
# ──────────────⎟    t⋅⎜─────────────────── + ─────────────────⎟ ⎥
#    2          ⎟      ⎜      2 ⎛ 2    ⎞            2          ⎟ ⎥
# 8⋅l ⋅(ν + 1)  ⎠      ⎝   4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠ ⎥
#                                                                ⎥
#                                                                ⎥
# (η - 1)⋅(ξ + 1)⎞      ⎛E⋅(1 - η)⋅(η - 1)   E⋅(ξ - 1)⋅(ξ + 1)⎞  ⎥
# ───────────────⎟    t⋅⎜───────────────── + ─────────────────⎟  ⎥
#     2          ⎟      ⎜      2                  2 ⎛ 2    ⎞  ⎟  ⎥
#  8⋅l ⋅(ν + 1)  ⎠      ⎝   8⋅l ⋅(ν + 1)       4⋅l ⋅⎝ν  - 1⎠  ⎠  ⎥
#                                                                ⎥
#                                                                ⎥
#  - ξ)⋅(ξ + 1)⎞      ⎛  E⋅ν⋅(η + 1)⋅(ξ + 1)   E⋅(1 - η)⋅(1 - ξ)⎞⎥
# ─────────────⎟    t⋅⎜- ─────────────────── + ─────────────────⎟⎥
#   2          ⎟      ⎜        2 ⎛ 2    ⎞            2          ⎟⎥
# ⋅l ⋅(ν + 1)  ⎠      ⎝     4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠⎥
#                                                                ⎥
#                                                                ⎥
# (η + 1)⋅(ξ + 1)⎞     ⎛  E⋅(1 - η)⋅(η + 1)   E⋅(1 - ξ)⋅(ξ + 1)⎞ ⎥
# ───────────────⎟   t⋅⎜- ───────────────── + ─────────────────⎟ ⎥
#     2          ⎟     ⎜        2                  2 ⎛ 2    ⎞  ⎟ ⎥
#  8⋅l ⋅(ν + 1)  ⎠     ⎝     8⋅l ⋅(ν + 1)       4⋅l ⋅⎝ν  - 1⎠  ⎠ ⎥
#                                                                ⎥
#          2 ⎞                                                   ⎥
# E⋅(ξ + 1)  ⎟         ⎛E⋅ν⋅(η + 1)⋅(ξ + 1)   E⋅(1 - η)⋅(ξ + 1)⎞ ⎥
# ───────────⎟       t⋅⎜─────────────────── + ─────────────────⎟ ⎥
#   2        ⎟         ⎜      2 ⎛ 2    ⎞            2          ⎟ ⎥
# ⋅l ⋅(ν + 1)⎠         ⎝   4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠ ⎥
#                                                                ⎥
#                         ⎛                               2 ⎞    ⎥
# (η + 1)⋅(ξ + 1)⎞        ⎜E⋅(1 - η)⋅(η + 1)     E⋅(ξ + 1)  ⎟    ⎥
# ───────────────⎟      t⋅⎜───────────────── + ─────────────⎟    ⎥
#     2          ⎟        ⎜      2                2 ⎛ 2    ⎞⎟    ⎥
#  8⋅l ⋅(ν + 1)  ⎠        ⎝   8⋅l ⋅(ν + 1)     4⋅l ⋅⎝ν  - 1⎠⎠    ⎥
#                                                                ⎥
#        2 ⎞                                                     ⎥
# (ξ + 1)  ⎟           ⎛E⋅ν⋅(1 - η)⋅(ξ + 1)   E⋅(1 - η)⋅(ξ + 1)⎞ ⎥
# ─────────⎟         t⋅⎜─────────────────── - ─────────────────⎟ ⎥
# 2        ⎟           ⎜      2 ⎛ 2    ⎞            2          ⎟ ⎥
#  ⋅(ν + 1)⎠           ⎝   4⋅l ⋅⎝ν  - 1⎠         8⋅l ⋅(ν + 1)  ⎠ ⎥
#                                                                ⎥
#                           ⎛          2               2 ⎞       ⎥
# 1 - η)⋅(ξ + 1)⎞           ⎜ E⋅(1 - η)       E⋅(ξ + 1)  ⎟       ⎥
# ──────────────⎟         t⋅⎜──────────── - ─────────────⎟       ⎥
#    2          ⎟           ⎜   2              2 ⎛ 2    ⎞⎟       ⎥
# 8⋅l ⋅(ν + 1)  ⎠           ⎝8⋅l ⋅(ν + 1)   4⋅l ⋅⎝ν  - 1⎠⎠       ⎦

# %%
K_matrix = K_matrix.integrate((qsi, -1, 1), (eta, -1, 1))

K_matrix = simplify(K_matrix)

K_matrix
# Out:
# ⎡2⋅E⋅t⋅(ν - 3)     -E⋅t          -2⋅E⋅ν⋅t     E⋅t⋅(3⋅ν - 1)   E⋅t⋅(3 - ν)
# ⎢─────────────  ────────────   ─────────────  ─────────────  ─────────────  ──
# ⎢   2 ⎛ 2    ⎞     2              2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2 ⎛ 2    ⎞
# ⎢3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠  2⋅
# ⎢
# ⎢   -E⋅t        2⋅E⋅t⋅(ν - 3)  E⋅t⋅(1 - 3⋅ν)   E⋅t⋅(ν + 3)       E⋅t        -E
# ⎢────────────   ─────────────  ─────────────  ─────────────  ────────────   ──
# ⎢   2              2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2
# ⎢2⋅l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1)   3⋅
# ⎢
# ⎢  -2⋅E⋅ν⋅t     E⋅t⋅(1 - 3⋅ν)  2⋅E⋅t⋅(ν - 3)      E⋅t         E⋅t⋅(ν + 3)   E⋅
# ⎢─────────────  ─────────────  ─────────────  ────────────   ─────────────  ──
# ⎢   2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2              2 ⎛ 2    ⎞
# ⎢3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠  2⋅
# ⎢
# ⎢E⋅t⋅(3⋅ν - 1)   E⋅t⋅(ν + 3)       E⋅t        2⋅E⋅t⋅(ν - 3)  E⋅t⋅(1 - 3⋅ν)
# ⎢─────────────  ─────────────  ────────────   ─────────────  ─────────────  ──
# ⎢   2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2              2 ⎛ 2    ⎞     2 ⎛ 2    ⎞
# ⎢2⋅l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠  3⋅
# ⎢
# ⎢ E⋅t⋅(3 - ν)       E⋅t         E⋅t⋅(ν + 3)   E⋅t⋅(1 - 3⋅ν)  2⋅E⋅t⋅(ν - 3)
# ⎢─────────────  ────────────   ─────────────  ─────────────  ─────────────  ──
# ⎢   2 ⎛ 2    ⎞     2              2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2 ⎛ 2    ⎞
# ⎢3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠  2⋅
# ⎢
# ⎢    E⋅t        -E⋅t⋅(ν - 3)   E⋅t⋅(3⋅ν - 1)    -2⋅E⋅ν⋅t        -E⋅t        2⋅
# ⎢────────────   ─────────────  ─────────────  ─────────────  ────────────   ──
# ⎢   2              2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2
# ⎢2⋅l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1)   3⋅
# ⎢
# ⎢ E⋅t⋅(ν + 3)   E⋅t⋅(3⋅ν - 1)   E⋅t⋅(3 - ν)      -E⋅t          -2⋅E⋅ν⋅t     E⋅
# ⎢─────────────  ─────────────  ─────────────  ────────────   ─────────────  ──
# ⎢   2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2              2 ⎛ 2    ⎞
# ⎢3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠  2⋅
# ⎢
# ⎢E⋅t⋅(1 - 3⋅ν)    -2⋅E⋅ν⋅t        -E⋅t        -E⋅t⋅(ν - 3)   E⋅t⋅(3⋅ν - 1)   E
# ⎢─────────────  ─────────────  ────────────   ─────────────  ─────────────  ──
# ⎢   2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2              2 ⎛ 2    ⎞     2 ⎛ 2    ⎞
# ⎣2⋅l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠  3⋅
#
#   E⋅t         E⋅t⋅(ν + 3)   E⋅t⋅(1 - 3⋅ν)⎤
# ──────────   ─────────────  ─────────────⎥
#  2              2 ⎛ 2    ⎞     2 ⎛ 2    ⎞⎥
# l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠⎥
#                                          ⎥
# ⋅t⋅(ν - 3)   E⋅t⋅(3⋅ν - 1)    -2⋅E⋅ν⋅t   ⎥
# ───────────  ─────────────  ─────────────⎥
#  2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2 ⎛ 2    ⎞⎥
# l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠⎥
#                                          ⎥
# t⋅(3⋅ν - 1)   E⋅t⋅(3 - ν)      -E⋅t      ⎥
# ───────────  ─────────────  ──────────── ⎥
#  2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2         ⎥
# l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1) ⎥
#                                          ⎥
# -2⋅E⋅ν⋅t        -E⋅t        -E⋅t⋅(ν - 3) ⎥
# ───────────  ────────────   ─────────────⎥
#  2 ⎛ 2    ⎞     2              2 ⎛ 2    ⎞⎥
# l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠⎥
#                                          ⎥
#  -E⋅t          -2⋅E⋅ν⋅t     E⋅t⋅(3⋅ν - 1)⎥
# ──────────   ─────────────  ─────────────⎥
#  2              2 ⎛ 2    ⎞     2 ⎛ 2    ⎞⎥
# l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠⎥
#                                          ⎥
# E⋅t⋅(ν - 3)  E⋅t⋅(1 - 3⋅ν)   E⋅t⋅(ν + 3) ⎥
# ───────────  ─────────────  ─────────────⎥
#  2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2 ⎛ 2    ⎞⎥
# l ⋅⎝ν  - 1⎠  2⋅l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠⎥
#                                          ⎥
# t⋅(1 - 3⋅ν)  2⋅E⋅t⋅(ν - 3)      E⋅t      ⎥
# ───────────  ─────────────  ──────────── ⎥
#  2 ⎛ 2    ⎞     2 ⎛ 2    ⎞     2         ⎥
# l ⋅⎝ν  - 1⎠  3⋅l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1) ⎥
#                                          ⎥
# ⋅t⋅(ν + 3)       E⋅t        2⋅E⋅t⋅(ν - 3)⎥
# ───────────  ────────────   ─────────────⎥
#  2 ⎛ 2    ⎞     2              2 ⎛ 2    ⎞⎥
# l ⋅⎝ν  - 1⎠  2⋅l ⋅(ν - 1)   3⋅l ⋅⎝ν  - 1⎠⎦

# %%
Eq(K, MatMul(E*t/(l**2 * (v - 1)), simplify(K_matrix/((E*t)/(l**2 * (v - 1))))), evaluate=False)
# Out:
#                ⎡                                                           ν
#                ⎢                                                       1 - ─
#                ⎢ 2⋅(ν - 3)                   -2⋅ν        3⋅ν - 1           3
#                ⎢ ─────────      -1/2        ───────     ─────────      ─────
#                ⎢ 3⋅(ν + 1)                  3⋅ν + 3     2⋅(ν + 1)      ν + 1
#                ⎢
#                ⎢
#                ⎢
#                ⎢              2⋅(ν - 3)   -(3⋅ν - 1)      ν + 3
#                ⎢   -1/2       ─────────   ───────────   ─────────       1/2
#                ⎢              3⋅(ν + 1)     2⋅ν + 2     3⋅(ν + 1)
#                ⎢
#                ⎢
#                ⎢
#                ⎢   -2⋅ν      -(3⋅ν - 1)    2⋅(ν - 3)                   ν + 3
#                ⎢  ───────    ───────────   ─────────       1/2       ─────────
#                ⎢  3⋅ν + 3      2⋅ν + 2     3⋅(ν + 1)                 3⋅(ν + 1)
#                ⎢
#                ⎢
#                ⎢
#                ⎢  3⋅ν - 1       ν + 3                   2⋅(ν - 3)   -(3⋅ν - 1)
#                ⎢ ─────────    ─────────       1/2       ─────────   ──────────
#        E⋅t     ⎢ 2⋅(ν + 1)    3⋅(ν + 1)                 3⋅(ν + 1)     2⋅ν + 2
# K = ──────────⋅⎢
#      2         ⎢       ν
#     l ⋅(ν - 1) ⎢   1 - ─
#                ⎢       3                     ν + 3     -(3⋅ν - 1)    2⋅(ν - 3)
#                ⎢   ─────         1/2       ─────────   ───────────   ─────────
#                ⎢   ν + 1                   3⋅(ν + 1)     2⋅ν + 2     3⋅(ν + 1)
#                ⎢
#                ⎢                    ν
#                ⎢                1 - ─
#                ⎢                    3       3⋅ν - 1       -2⋅ν
#                ⎢    1/2         ─────      ─────────     ───────       -1/2
#                ⎢                ν + 1      2⋅(ν + 1)     3⋅ν + 3
#                ⎢
#                ⎢                                 ν
#                ⎢                             1 - ─
#                ⎢   ν + 3       3⋅ν - 1           3                     -2⋅ν
#                ⎢ ─────────    ─────────      ─────        -1/2        ───────
#                ⎢ 3⋅(ν + 1)    2⋅(ν + 1)      ν + 1                    3⋅ν + 3
#                ⎢
#                ⎢                                              ν
#                ⎢                                          1 - ─
#                ⎢-(3⋅ν - 1)      -2⋅ν                          3       3⋅ν - 1
#                ⎢───────────    ───────       -1/2         ─────      ─────────
#                ⎣  2⋅ν + 2      3⋅ν + 3                    ν + 1      2⋅(ν + 1)
#
#                                         ⎤
#                                         ⎥
#                    ν + 3     -(3⋅ν - 1) ⎥
#        1/2       ─────────   ───────────⎥
#                  3⋅(ν + 1)     2⋅ν + 2  ⎥
#                                         ⎥
#           ν                             ⎥
#       1 - ─                             ⎥
#           3       3⋅ν - 1       -2⋅ν    ⎥
#       ─────      ─────────     ───────  ⎥
#       ν + 1      2⋅(ν + 1)     3⋅ν + 3  ⎥
#                                         ⎥
#                        ν                ⎥
#                    1 - ─                ⎥
#      3⋅ν - 1           3                ⎥
#     ─────────      ─────        -1/2    ⎥
#     2⋅(ν + 1)      ν + 1                ⎥
#                                         ⎥
#                                     ν   ⎥
#                                 1 - ─   ⎥
#       -2⋅ν                          3   ⎥
# ─    ───────       -1/2         ─────   ⎥
#      3⋅ν + 3                    ν + 1   ⎥
#                                         ⎥
#                                         ⎥
#                                         ⎥
#                    -2⋅ν        3⋅ν - 1  ⎥
#       -1/2        ───────     ───────── ⎥
#                   3⋅ν + 3     2⋅(ν + 1) ⎥
#                                         ⎥
#                                         ⎥
#                                         ⎥
#     2⋅(ν - 3)   -(3⋅ν - 1)      ν + 3   ⎥
#     ─────────   ───────────   ───────── ⎥
#     3⋅(ν + 1)     2⋅ν + 2     3⋅(ν + 1) ⎥
#                                         ⎥
#                                         ⎥
#                                         ⎥
#    -(3⋅ν - 1)    2⋅(ν - 3)              ⎥
#    ───────────   ─────────       1/2    ⎥
#      2⋅ν + 2     3⋅(ν + 1)              ⎥
#                                         ⎥
#                                         ⎥
#                                         ⎥
#       ν + 3                   2⋅(ν - 3) ⎥
#     ─────────       1/2       ───────── ⎥
#     3⋅(ν + 1)                 3⋅(ν + 1) ⎦

# %%
# Out:
# ⎡
# ⎢
# ⎢   2⋅E⋅t⋅(ν - 3)             -E⋅t                -2⋅E⋅ν⋅t            E⋅t⋅(3⋅ν
# ⎢────────────────────      ────────────      ────────────────────  ───────────
# ⎢   2                         2               2                       2
# ⎢3⋅l ⋅(ν - 1)⋅(ν + 1)      2⋅l ⋅(ν - 1)      l ⋅(ν - 1)⋅(3⋅ν + 3)  2⋅l ⋅(ν - 1
# ⎢
# ⎢
# ⎢
# ⎢       -E⋅t              2⋅E⋅t⋅(ν - 3)        -E⋅t⋅(3⋅ν - 1)          E⋅t⋅(ν
# ⎢    ────────────      ────────────────────  ────────────────────  ───────────
# ⎢       2                 2                   2                       2
# ⎢    2⋅l ⋅(ν - 1)      3⋅l ⋅(ν - 1)⋅(ν + 1)  l ⋅(ν - 1)⋅(2⋅ν + 2)  3⋅l ⋅(ν - 1
# ⎢
# ⎢
# ⎢
# ⎢     -2⋅E⋅ν⋅t           -E⋅t⋅(3⋅ν - 1)         2⋅E⋅t⋅(ν - 3)              E⋅t
# ⎢────────────────────  ────────────────────  ────────────────────      ───────
# ⎢ 2                     2                       2                         2
# ⎢l ⋅(ν - 1)⋅(3⋅ν + 3)  l ⋅(ν - 1)⋅(2⋅ν + 2)  3⋅l ⋅(ν - 1)⋅(ν + 1)      2⋅l ⋅(ν
# ⎢
# ⎢
# ⎢
# ⎢   E⋅t⋅(3⋅ν - 1)          E⋅t⋅(ν + 3)               E⋅t              2⋅E⋅t⋅(ν
# ⎢────────────────────  ────────────────────      ────────────      ───────────
# ⎢   2                     2                         2                 2
# ⎢2⋅l ⋅(ν - 1)⋅(ν + 1)  3⋅l ⋅(ν - 1)⋅(ν + 1)      2⋅l ⋅(ν - 1)      3⋅l ⋅(ν - 1
# ⎢
# ⎢        ⎛    ν⎞
# ⎢    E⋅t⋅⎜1 - ─⎟
# ⎢        ⎝    3⎠               E⋅t               E⋅t⋅(ν + 3)         -E⋅t⋅(3⋅ν
# ⎢ ──────────────────       ────────────      ────────────────────  ───────────
# ⎢  2                          2                 2                   2
# ⎢ l ⋅(ν - 1)⋅(ν + 1)       2⋅l ⋅(ν - 1)      3⋅l ⋅(ν - 1)⋅(ν + 1)  l ⋅(ν - 1)⋅
# ⎢
# ⎢                              ⎛    ν⎞
# ⎢                          E⋅t⋅⎜1 - ─⎟
# ⎢        E⋅t                   ⎝    3⎠          E⋅t⋅(3⋅ν - 1)           -2⋅E⋅ν
# ⎢    ────────────       ──────────────────   ────────────────────  ───────────
# ⎢       2                2                      2                   2
# ⎢    2⋅l ⋅(ν - 1)       l ⋅(ν - 1)⋅(ν + 1)   2⋅l ⋅(ν - 1)⋅(ν + 1)  l ⋅(ν - 1)⋅
# ⎢
# ⎢                                                    ⎛    ν⎞
# ⎢                                                E⋅t⋅⎜1 - ─⎟
# ⎢    E⋅t⋅(ν + 3)          E⋅t⋅(3⋅ν - 1)              ⎝    3⎠              -E⋅t
# ⎢────────────────────  ────────────────────   ──────────────────       ───────
# ⎢   2                     2                    2                          2
# ⎢3⋅l ⋅(ν - 1)⋅(ν + 1)  2⋅l ⋅(ν - 1)⋅(ν + 1)   l ⋅(ν - 1)⋅(ν + 1)       2⋅l ⋅(ν
# ⎢
# ⎢                                                                          ⎛
# ⎢                                                                      E⋅t⋅⎜1
# ⎢  -E⋅t⋅(3⋅ν - 1)           -2⋅E⋅ν⋅t                -E⋅t                   ⎝
# ⎢────────────────────  ────────────────────      ────────────       ──────────
# ⎢ 2                     2                           2                2
# ⎣l ⋅(ν - 1)⋅(2⋅ν + 2)  l ⋅(ν - 1)⋅(3⋅ν + 3)      2⋅l ⋅(ν - 1)       l ⋅(ν - 1)
#
#                    ⎛    ν⎞
#                E⋅t⋅⎜1 - ─⎟
#  - 1)              ⎝    3⎠               E⋅t               E⋅t⋅(ν + 3)
# ─────────   ──────────────────       ────────────      ────────────────────  ─
#              2                          2                 2
# )⋅(ν + 1)   l ⋅(ν - 1)⋅(ν + 1)       2⋅l ⋅(ν - 1)      3⋅l ⋅(ν - 1)⋅(ν + 1)  l
#
#                                          ⎛    ν⎞
#                                      E⋅t⋅⎜1 - ─⎟
# + 3)               E⋅t                   ⎝    3⎠          E⋅t⋅(3⋅ν - 1)
# ─────────      ────────────       ──────────────────   ────────────────────  ─
#                   2                2                      2
# )⋅(ν + 1)      2⋅l ⋅(ν - 1)       l ⋅(ν - 1)⋅(ν + 1)   2⋅l ⋅(ν - 1)⋅(ν + 1)  l
#
#                                                                ⎛    ν⎞
#                                                            E⋅t⋅⎜1 - ─⎟
#                E⋅t⋅(ν + 3)          E⋅t⋅(3⋅ν - 1)              ⎝    3⎠
# ─────      ────────────────────  ────────────────────   ──────────────────
#               2                     2                    2
#  - 1)      3⋅l ⋅(ν - 1)⋅(ν + 1)  2⋅l ⋅(ν - 1)⋅(ν + 1)   l ⋅(ν - 1)⋅(ν + 1)
#
#
#
#  - 3)        -E⋅t⋅(3⋅ν - 1)           -2⋅E⋅ν⋅t                -E⋅t
# ─────────  ────────────────────  ────────────────────      ────────────
#             2                     2                           2
# )⋅(ν + 1)  l ⋅(ν - 1)⋅(2⋅ν + 2)  l ⋅(ν - 1)⋅(3⋅ν + 3)      2⋅l ⋅(ν - 1)
#
#
#
#  - 1)         2⋅E⋅t⋅(ν - 3)             -E⋅t                -2⋅E⋅ν⋅t
# ─────────  ────────────────────      ────────────      ────────────────────  ─
#               2                         2               2
# (2⋅ν + 2)  3⋅l ⋅(ν - 1)⋅(ν + 1)      2⋅l ⋅(ν - 1)      l ⋅(ν - 1)⋅(3⋅ν + 3)  2
#
#
#
# ⋅t                -E⋅t              2⋅E⋅t⋅(ν - 3)        -E⋅t⋅(3⋅ν - 1)
# ─────────      ────────────      ────────────────────  ────────────────────  ─
#                   2                 2                   2
# (3⋅ν + 3)      2⋅l ⋅(ν - 1)      3⋅l ⋅(ν - 1)⋅(ν + 1)  l ⋅(ν - 1)⋅(2⋅ν + 2)  3
#
#
#
#                 -2⋅E⋅ν⋅t           -E⋅t⋅(3⋅ν - 1)         2⋅E⋅t⋅(ν - 3)
# ─────      ────────────────────  ────────────────────  ────────────────────
#             2                     2                       2
#  - 1)      l ⋅(ν - 1)⋅(3⋅ν + 3)  l ⋅(ν - 1)⋅(2⋅ν + 2)  3⋅l ⋅(ν - 1)⋅(ν + 1)
#
#   ν⎞
# - ─⎟
#   3⎠          E⋅t⋅(3⋅ν - 1)          E⋅t⋅(ν + 3)               E⋅t
# ────────   ────────────────────  ────────────────────      ────────────      ─
#               2                     2                         2
# ⋅(ν + 1)   2⋅l ⋅(ν - 1)⋅(ν + 1)  3⋅l ⋅(ν - 1)⋅(ν + 1)      2⋅l ⋅(ν - 1)      3
#
#                    ⎤
#                    ⎥
#  -E⋅t⋅(3⋅ν - 1)    ⎥
# ───────────────────⎥
# 2                  ⎥
#  ⋅(ν - 1)⋅(2⋅ν + 2)⎥
#                    ⎥
#                    ⎥
#                    ⎥
#     -2⋅E⋅ν⋅t       ⎥
# ───────────────────⎥
# 2                  ⎥
#  ⋅(ν - 1)⋅(3⋅ν + 3)⎥
#                    ⎥
#                    ⎥
#                    ⎥
#       -E⋅t         ⎥
#    ────────────    ⎥
#       2            ⎥
#    2⋅l ⋅(ν - 1)    ⎥
#                    ⎥
#        ⎛    ν⎞     ⎥
#    E⋅t⋅⎜1 - ─⎟     ⎥
#        ⎝    3⎠     ⎥
# ────────────────── ⎥
#  2                 ⎥
# l ⋅(ν - 1)⋅(ν + 1) ⎥
#                    ⎥
#                    ⎥
#                    ⎥
#   E⋅t⋅(3⋅ν - 1)    ⎥
# ───────────────────⎥
#   2                ⎥
# ⋅l ⋅(ν - 1)⋅(ν + 1)⎥
#                    ⎥
#                    ⎥
#                    ⎥
#    E⋅t⋅(ν + 3)     ⎥
# ───────────────────⎥
#   2                ⎥
# ⋅l ⋅(ν - 1)⋅(ν + 1)⎥
#                    ⎥
#                    ⎥
#                    ⎥
#        E⋅t         ⎥
#    ────────────    ⎥
#       2            ⎥
#    2⋅l ⋅(ν - 1)    ⎥
#                    ⎥
#                    ⎥
#                    ⎥
#   2⋅E⋅t⋅(ν - 3)    ⎥
# ───────────────────⎥
#   2                ⎥
# ⋅l ⋅(ν - 1)⋅(ν + 1)⎦
